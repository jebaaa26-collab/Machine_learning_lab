# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data={
    "name":["jeba","yamu","swe"],"age":[19,17,15],"marks":[90,85,95]}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    name  age  marks
# 0  jeba   19     90
# 1  yamu   17     85
# 2   swe   15     95

# %%
df.head()
# Out:
#    name  age  marks
# 0  jeba   19     90
# 1  yamu   17     85
# 2   swe   15     95

# %%
df.tail()
# Out:
#    name  age  marks
# 0  jeba   19     90
# 1  yamu   17     85
# 2   swe   15     95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   marks   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#         age  marks
# count   3.0    3.0
# mean   17.0   90.0
# std     2.0    5.0
# min    15.0   85.0
# 25%    16.0   87.5
# 50%    17.0   90.0
# 75%    18.0   92.5
# max    19.0   95.0

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'marks'], dtype='object')

# %%
print(df["name"])
# Out:
# 0    jeba
# 1    yamu
# 2     swe
# Name: name, dtype: object

# %%
print(df[["name","marks"]])
# Out:
#    name  marks
# 0  jeba     90
# 1  yamu     85
# 2   swe     95

# %%
print(df.iloc[1])
# Out:
# name     yamu
# age        17
# marks      85
# Name: 1, dtype: object

# %%
print(df[df["marks"]>90])
# Out:
#   name  age  marks
# 2  swe   15     95

# %%
df.sort_values("marks")
# Out:
#    name  age  marks
# 1  yamu   17     85
# 0  jeba   19     90
# 2   swe   15     95

# %%
df.sort_values("marks",ascending=False)
# Out:
#    name  age  marks
# 2   swe   15     95
# 0  jeba   19     90
# 1  yamu   17     85

# %%
df.dropna()
# Out:
#    name  age  marks
# 0  jeba   19     90
# 1  yamu   17     85
# 2   swe   15     95
